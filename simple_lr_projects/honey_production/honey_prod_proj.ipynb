# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <p style="text-align: center; font-size: 28px;"><b>Honey Production</b></p>
#
#
# Now let’s apply it to a real-world dataset.
#
# As you might know, honeybee populations are currently facing serious challenges. You’ve likely come across articles highlighting their decline, caused by multiple factors. In this project, you’ll analyze these trends and explore how past data can be used to forecast the future of honeybee populations.
#
# Note: You can use either Pandas or NumPy to complete the tasks—choose whichever you’re more comfortable with.
#
# If you run into difficulties or want to see how an experienced developer approaches the project, click **“Get Unstuck”** for a step-by-step walkthrough video.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv("honeyproduction.csv")

# %% [markdown]
# 1. A DataFrame containing honey production data in the United States from Kaggle has already been loaded. The variable is named df and includes the following columns:
#
# - state
# - numcol
# - yieldpercol
# - totalprod
# - stocks
# - priceperlb
# - prodvalue
# - year
#
# Use .head() to preview the structure of this DataFrame.

# %%
df.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %% [markdown]
# 2. Focus on the total honey production per year. Apply the `.groupby()` method from pandas to calculate the mean of `totalprod` for each year, and assign the result to a variable named `prod_per_year`.

# %%
prod_per_year = df.groupby("year").totalprod.mean().reset_index()
prod_per_year
# Out:
#     year     totalprod
# 0   1998  5.105093e+06
# 1   1999  4.706674e+06
# 2   2000  5.106000e+06
# 3   2001  4.221545e+06
# 4   2002  3.892386e+06
# 5   2003  4.122091e+06
# 6   2004  4.456805e+06
# 7   2005  4.243146e+06
# 8   2006  3.761902e+06
# 9   2007  3.600512e+06
# 10  2008  3.974927e+06
# 11  2009  3.626700e+06
# 12  2010  4.382350e+06
# 13  2011  3.680025e+06
# 14  2012  3.522675e+06

# %% [markdown]
# 3. Define a variable X containing the year column from the prod_per_year DataFrame and reshape X into the correct format.

# %%
X = prod_per_year["year"]
print(type(X))
X = X.values.reshape(-1, 1)
print(type(X))
print(X.shape)
print(type(X))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'numpy.ndarray'>
# (15, 1)
# <class 'numpy.ndarray'>

# %% [markdown]
# 4. Create a variable called y that is the totalprod column in the prod_per_year dataset.

# %%
y = prod_per_year["totalprod"]
print(type(y))
y = y.values.reshape(-1, 1)
print(type(y))
print(y.shape)
print(type(y))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'numpy.ndarray'>
# (15, 1)
# <class 'numpy.ndarray'>

# %% [markdown]
# 5. Using plt.scatter(), plot y vs X as a scatterplot.
#
# Display the plot using plt.show().
#
# Can you see a vaguely linear relationship between these variables?

# %%
plt.scatter(X, y)
plt.title("Honey Production in the US: Total Production per Year")
plt.xlabel("Year")
plt.ylabel("Total Production")
plt.show()

# %% [markdown]
# 6. Create a linear regression model from scikit-learn and call it regr.
#
# Use the LinearRegression() constructor from the linear_model module to do this.

# %%
regr =linear_model. LinearRegression()

# %% [markdown]
# 7. Fit the model to the data by using .fit(). You can feed X into your regr model by passing it in as a parameter of .fit().

# %%
regr.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# 8. After you have fit the model, print out the slope of the line (stored in a list called regr.coef_) and the intercept of the line (regr.intercept_).

# %%
print(regr.coef_)
print(regr.intercept_)
# Out:
# [[-88303.18915238]]
# [1.81208083e+08]

# %% [markdown]
# 9. Create a list called y_predict that is the predictions your regr model would make on the X data.

# %%
y_pred = regr.predict(X)

# %% [markdown]
# 10. Plot y_predict vs X as a line, on top of your scatterplot using plt.plot().
#
# Make sure to call plt.show() after plotting the line.

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color = "red")
plt.title("Honey Production in the US: Total Production per Year")
plt.xlabel("Year")
plt.ylabel("Total Production")
plt.show()

# %% [markdown]
# 11. So, it looks like the production of honey has been in decline, according to this linear model. Let’s predict what the year 2050 may look like in terms of honey production.
#
# Our known dataset stops at the year 2013, so let’s create a NumPy array called X_future that is the range from 2013 to 2050. The code below makes a NumPy array with the numbers 1 through 10
#
# After creating that array, we need to reshape it for scikit-learn.
#
# You can think of reshape() as rotating this array. Rather than one big row of numbers, X_future is now a big column of numbers — there’s one number in each row.

# %%
X_future = np.array(range(2013, 2051))
print(X_future)
# Out:
# [2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024 2025 2026
#  2027 2028 2029 2030 2031 2032 2033 2034 2035 2036 2037 2038 2039 2040
#  2041 2042 2043 2044 2045 2046 2047 2048 2049 2050]

# %%
X_future = X_future.reshape(-1, 1)
print(X_future)
# Out:
# [[2013]
#  [2014]
#  [2015]
#  [2016]
#  [2017]
#  [2018]
#  [2019]
#  [2020]
#  [2021]
#  [2022]
#  [2023]
#  [2024]
#  [2025]
#  [2026]
#  [2027]
#  [2028]
#  [2029]
#  [2030]
#  [2031]
#  [2032]
#  [2033]
#  [2034]
#  [2035]
#  [2036]
#  [2037]
#  [2038]
#  [2039]
#  [2040]
#  [2041]
#  [2042]
#  [2043]
#  [2044]
#  [2045]
#  [2046]
#  [2047]
#  [2048]
#  [2049]
#  [2050]]

# %% [markdown]
# 12. Create a list called future_predict that is the y-values that your regr model would predict for the values of X_future.

# %%
future_predict= regr.predict(X_future)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Left graph: scatter + regression line
axes[0].scatter(X, y)
axes[0].plot(X, y_pred, color="red")
axes[0].set_title("Honey Production: Historical Trend")
axes[0].set_xlabel("Year")
axes[0].set_ylabel("Total Production")

# Right graph: future prediction
axes[1].plot(X_future, future_predict, color="red")
axes[1].set_title("Honey Production: Future Prediction")
axes[1].set_xlabel("Year")
axes[1].set_ylabel("Total Production")

plt.tight_layout()
plt.show()
